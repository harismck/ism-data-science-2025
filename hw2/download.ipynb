# %%
###
# Create a copy of this notebook, then run this cell.
# After downloading the folder, delete this cell.
###
import gdown

folder_url = "https://drive.google.com/drive/folders/10Sm_mCU5f3EPufKefGaLco1uKthBzzWe"
gdown.download_folder(url=folder_url, output="transport", quiet=False)
# Out:
# Retrieving folder contents
# Processing file 1j_Vc0tbcB5yxtFrEWpAjRP9YoKwbM3sl docs.md
# Processing file 1OGq4CfL0gnGmj6pg1S2xVZrWq5r6HGKF inspection.parquet
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1j_Vc0tbcB5yxtFrEWpAjRP9YoKwbM3sl
# To: /Users/haroldas.mackevicius/personal/ism-data-science-2025/transport/docs.md
# 100%|██████████| 3.15k/3.15k [00:00<00:00, 10.1MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1OGq4CfL0gnGmj6pg1S2xVZrWq5r6HGKF
# From (redirected): https://drive.google.com/uc?id=1OGq4CfL0gnGmj6pg1S2xVZrWq5r6HGKF&confirm=t&uuid=c13ee8c3-9bad-48ff-bd96-26151bd3f85d
# To: /Users/haroldas.mackevicius/personal/ism-data-science-2025/transport/inspection.parquet
# 100%|██████████| 581M/581M [00:11<00:00, 52.7MB/s]
# Download completed
# ['transport/docs.md', 'transport/inspection.parquet']

# %%
import pandas as pd

# %%
pd.read_parquet("transport/inspection.parquet").sample(5)
# Out:
#         unique_identifier vehicle_identifier registration_number  \
# 6489590   8dede1bfe3c9094    9b17d8e5bc8e159     d3be25ede6c1f7a
# 7573340   a5a386a254b6cd6    8096c6455581904     e179bd803baf3ad
# 3187075   45c1c7e83d608ad    d04954eff65e372     7103a5b5bf947ba
# 4330489   5ea0bc0b2242cf3    d29a219750b0d4f     66ae90cccca7fc4
# 9050265   c5f0fcd4e9a1f65    3aa75f576ad642b     019d66fbf7c0d5c
#
#         registration_number_markings       vin_number   make        model  \
# 6489590                         None  5a589c91dc6a791  VOLVO          V70
# 7573340                         None  c6a8192c3ffa330  LEXUS       IS 200
# 3187075                         None  454100bc3a330da    MAZ         5551
# 4330489                         None  72cbf38fb9e7a96    MAN       18.224
# 9050265                         None  2c16004b062f773    KIA  PICANTO, SA
#
#         class body_type special_purpose  ...  mileage_km  \
# 6489590    M1        AC            None  ...    527363.0
# ...
